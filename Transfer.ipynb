# %%
import copy
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Lasso, SGDRegressor
from sklearn.neural_network import MLPRegressor

# from nnpred import nn_train, nn_pred, nn_finetune
from nnpred import *

# from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima import auto_arima



from utils import  MAPE, SMAPE, RMSE, MAE

# %% [markdown]
# ### read data

# %%
city_list =['Perth', 'HK', 'PALO', 'DUNDEE', 'BOULDER','Auchterarder','Kinross','Pitlochry','Crieff','Aberfeldy','Dunkeld','Blairgowrie']
city_num = 12

data_list = []
file_list = [
    './Data/STATION/A1-PERTH.csv',
    './Data/STATION/A2-XIANGGANG.csv',
    './Data/STATION/A3-PALO.csv',
    './Data/STATION/A4-DUNDEE.csv',
    './Data/STATION/A5-BOULDER.csv',
    './Data/STATION/A6-Auchterarder.csv',
    './Data/STATION/A7-Kinross.csv',
    './Data/STATION/A8-Pitlochry.csv',
    './Data/STATION/A9-Crieff.csv',
    './Data/STATION/A10-Aberfeldy.csv',
    './Data/STATION/A11-Dunkeld.csv',
    './Data/STATION/A12-Blairgowrie.csv'

]

for file in file_list:

    data = pd.read_csv(file).values
    data_list.append(data[:,1:])
    

# prediction settings

his_len = 6
pred_len = 3

# models

# model_name = 'RF'
# model_name = 'MLP'
# model_name = 'LASSO'
# model_name = 'SGD'
model_name = 'LSTM'
# model_name = 'GRU'

# %%
for i in range(city_num):

    print(city_list[i], data_list[i].mean())
# Out:
# Perth 1.2238425925925926
# HK 1.1412760416666667
# PALO 0.7468253968253968
# DUNDEE 1.0719832735961767
# BOULDER 0.22690058479532163
# Auchterarder 0.26666666666666666
# Kinross 0.3506944444444444
# Pitlochry 0.45092592592592595
# Crieff 0.5555555555555556
# Aberfeldy 0.5513888888888889
# Dunkeld 0.24444444444444444
# Blairgowrie 0.26944444444444443

# %% [markdown]
# ### get train and test data

# %%
def get_train_test (data, mode, his_len = 12, pred_len = 3, train_rate = 0.8):

    train_num = int(data.shape[0] * train_rate)
    XS, YS = [], []
    if mode == 'train':
        for i in range(train_num - pred_len - his_len + 1):
            x = data[i:i + his_len, :]
            y = data[i + his_len:i + his_len + pred_len, :]
            XS.append(x), YS.append(y)
    elif mode == 'test':
        for i in range(train_num - his_len,
                       data.shape[0] - pred_len - his_len + 1):
            x = data[i:i + his_len, :]
            y = data[i + his_len:i + his_len + pred_len, :]
            XS.append(x), YS.append(y)

    XS, YS = np.array(XS), np.array(YS)
    XS, YS = np.squeeze(XS), np.squeeze(YS)
    
    return XS, YS

# %%
# train test split

train_list = []
test_list = []
scaler_list = []
sensor_num_list = []

for data in data_list:

    # data = np.reshape(data, (-1,1))
    scaler = StandardScaler()
    data = scaler.fit_transform(data)
    
    train_x, train_y = get_train_test (data, 'train', his_len, pred_len, train_rate = 0.8 )
    test_x, test_y = get_train_test (data, 'test', his_len, pred_len, train_rate = 0.8)

    sensor_num_list.append(data.shape[1])

    train_x = np.reshape(train_x, (-1, his_len))
    train_y = np.reshape(train_y, (-1, pred_len))
    test_x = np.reshape(test_x, (-1, his_len))
    test_y = np.reshape(test_y, (-1, pred_len))



    train_list.append([train_x, train_y])
    test_list.append([test_x, test_y])
    scaler_list.append(scaler)

# %%
train_list[0][0].shape
# Out:
# (3408, 6)

# %% [markdown]
# ### training and testing

# %%
# source, target, metric
transfer_rec = np.zeros((city_num, city_num, 4))
wo_transfer_rec = np.zeros((city_num, 4))

for source_idx in range(city_num):
    # train on the source city
    # source_idx = 0
    print('-------------------------------')
    print('-------Source city: {:s}-------'.format(city_list[source_idx]))
    print('-------------------------------')

    source_x, source_y = train_list[source_idx]
    print(source_x.shape, source_y.shape)


    if model_name == 'RF':
        model = RandomForestRegressor(max_depth=2, random_state=0, warm_start=True)
        model.fit(source_x, source_y)
    elif model_name == 'MLP':
        model = MLPRegressor(random_state=0, warm_start=True)
        model.fit(source_x, source_y)
    elif model_name == 'LASSO':
        model = Lasso(random_state=0, warm_start=True)
        model.fit(source_x, source_y)
    elif model_name == 'SGD':
        model = SGDRegressor(random_state=0, warm_start=True)
        model.fit(source_x, np.mean(source_y, axis=1))
    elif model_name == 'LSTM' or model_name == 'GRU':
        model = nn_train(source_x, source_y, model_name, learning_rate=1e-2)

    else:
        pass

    # test on the source city
    test_x, test_y = test_list[source_idx]

    if model_name == 'RF' or model_name == 'MLP' or model_name == 'LASSO':
        pred_y = model.predict(test_x)
    elif model_name == 'SGD':
        pred_y = model.predict(test_x)
        pred_y = np.reshape(pred_y, (-1, 1))
        pred_y = pred_y.repeat(pred_len ,axis=1)
    elif model_name == 'LSTM' or model_name == 'GRU':
        pred_y = nn_pred(test_x, test_y, model)

    else:
        pass

    test_y = np.reshape(test_y, (-1, sensor_num_list[source_idx], pred_len))
    pred_y = np.reshape(pred_y, (-1, sensor_num_list[source_idx], pred_len))

    test_y = scaler_list[source_idx].inverse_transform(test_y.transpose(0,2,1))
    pred_y = scaler_list[source_idx].inverse_transform(pred_y.transpose(0,2,1))
    pred_y = np.around(pred_y.astype(np.float32))
    pred_y [pred_y < 0] = 0

    mape, smape, rmse, mae = MAPE(test_y, pred_y), SMAPE(test_y, pred_y), RMSE(test_y, pred_y), MAE(test_y, pred_y)

    print('Test MAPE1: SMAPE: RMSE:  MAE: | {:.4f} | {:.4f} | {:.4f} | {:.4f}'.format(mape, smape, rmse, mae))

    transfer_rec[source_idx, source_idx, 0] = mape
    transfer_rec[source_idx, source_idx, 1] = smape 
    transfer_rec[source_idx, source_idx, 2] = rmse 
    transfer_rec[source_idx, source_idx, 3] = mae 


    # transfer to other cities
    for target_idx in range(city_num):

        if target_idx == source_idx:
            continue
    # target_idx = 1
        print('-------Target city: {:s}--------'.format(city_list[target_idx]))


        ###################
        #transfer
        ###################
        source_model = copy.copy(model)

        target_x, target_y = train_list[target_idx]
        # target_x = target_x[-24+his_len:, ]
        # target_y = target_y[-24+his_len:, ]
        target_x = target_x[(-24+his_len)*sensor_num_list[target_idx]:, ]
        target_y = target_y[(-24+his_len)*sensor_num_list[target_idx]:, ]
        print(target_x.shape, target_y.shape)

        test_x, test_y = test_list[target_idx]
        # transfer train and test
        if model_name == 'RF' or model_name == 'MLP'  or model_name == 'LASSO':
            source_model.fit(target_x, target_y)
            pred_y = source_model.predict(test_x)

        elif model_name == 'SGD':
            source_model.fit(target_x, np.mean(target_y, axis=1))
            pred_y = source_model.predict(test_x)
            pred_y = np.reshape(pred_y, (-1, 1))
            pred_y = pred_y.repeat(pred_len ,axis=1)
        elif model_name == 'LSTM' or model_name == 'GRU':
            source_model = nn_finetune(test_x, test_y, source_model)
            pred_y = nn_pred(test_x, test_y, source_model)

        else:
            pass

        test_y = np.reshape(test_y, (-1, sensor_num_list[target_idx], pred_len))
        pred_y = np.reshape(pred_y, (-1, sensor_num_list[target_idx], pred_len))
        test_y = scaler_list[target_idx].inverse_transform(test_y.transpose(0,2,1))
        pred_y = scaler_list[target_idx].inverse_transform(pred_y.transpose(0,2,1))
        pred_y = np.around(pred_y.astype(np.float32))
        pred_y [pred_y < 0] = 0

        mape, smape, rmse, mae = MAPE(test_y, pred_y), SMAPE(test_y, pred_y), RMSE(test_y, pred_y), MAE(test_y, pred_y)

        print('Transfer Test MAPE1: SMAPE: RMSE:  MAE: | {:.4f} | {:.4f} | {:.4f} | {:.4f}'.format(mape, smape, rmse, mae))

        transfer_rec[source_idx, target_idx, 0] = mape
        transfer_rec[source_idx, target_idx, 1] = smape 
        transfer_rec[source_idx, target_idx, 2] = rmse 
        transfer_rec[source_idx, target_idx, 3] = mae 


        ###################
        # with out transfer
        ###################
        test_x, test_y = test_list[target_idx]

        if model_name == 'RF':
            wo_trans_model = RandomForestRegressor(max_depth=2, random_state=0)
            wo_trans_model.fit(target_x, target_y)
            pred_y = wo_trans_model.predict(test_x)

        elif model_name == 'MLP':
            wo_trans_model = MLPRegressor(random_state=0)
            wo_trans_model.fit(target_x, target_y)
            pred_y = wo_trans_model.predict(test_x)

        elif model_name == 'LASSO':
            wo_trans_model = MLPRegressor(random_state=0)
            wo_trans_model.fit(target_x, target_y)
            pred_y = wo_trans_model.predict(test_x)
        elif model_name == 'SGD':
            wo_trans_model = SGDRegressor(random_state=0)
            wo_trans_model.fit(target_x, np.mean(target_y, axis=1))
            pred_y = wo_trans_model.predict(test_x)
            pred_y = np.reshape(pred_y, (-1, 1))
            pred_y = pred_y.repeat(pred_len ,axis=1)
        elif model_name == 'LSTM' or model_name == 'GRU':
            wo_trans_model = nn_train(target_x, target_y, model_name, learning_rate=1e-2)
            pred_y = nn_pred(test_x, test_y, wo_trans_model)

        else:
            pass

        test_y = np.reshape(test_y, (-1, sensor_num_list[target_idx], pred_len))
        pred_y = np.reshape(pred_y, (-1, sensor_num_list[target_idx], pred_len))

        test_y = scaler_list[target_idx].inverse_transform(test_y.transpose(0,2,1))
        pred_y = scaler_list[target_idx].inverse_transform(pred_y.transpose(0,2,1))
        pred_y = np.around(pred_y.astype(np.float32))
        pred_y [pred_y < 0] = 0

        mape, smape, rmse, mae = MAPE(test_y, pred_y), SMAPE(test_y, pred_y), RMSE(test_y, pred_y), MAE(test_y, pred_y)

        print('Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | {:.4f} | {:.4f} | {:.4f} | {:.4f}'.format(mape, smape, rmse, mae))

        wo_transfer_rec[target_idx, 0] = mape
        wo_transfer_rec[target_idx, 1] = smape 
        wo_transfer_rec[target_idx, 2] = rmse 
        wo_transfer_rec[target_idx, 3] = mae
# Out:
# -------------------------------
# -------Source city: Perth-------
# -------------------------------
# (3408, 6) (3408, 3)
# Early stopping at epoch: 69
# epoch 69 train loss: 0.5080679432924233 validation loss: 0.5376105904579163
# Test MAPE1: SMAPE: RMSE:  MAE: | 0.2824 | 0.4091 | 0.8395 | 0.4811
# -------Target city: HK--------
# (180, 6) (180, 3)
# Early stopping at epoch: 55
# epoch 55 train loss: 0.8996727693150615 validation loss: 0.47997573018074036
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2075 | 0.1908 | 0.8220 | 0.5421
# Early stopping at epoch: 24
# epoch 24 train loss: 0.8132673501968384 validation loss: 0.9421013593673706
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3196 | 0.4577 | 0.7618 | 0.5827
# -------Target city: PALO--------
# (126, 6) (126, 3)
# Early stopping at epoch: 23
# epoch 23 train loss: 0.8119732737541199 validation loss: 1.0458014011383057
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5027 | 0.8253 | 1.0028 | 0.7739
# Early stopping at epoch: 45
# epoch 45 train loss: 0.6855440735816956 validation loss: 0.5802766680717468
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.4334 | 0.6583 | 1.0091 | 0.8080
# -------Target city: DUNDEE--------
# (486, 6) (486, 3)
# Early stopping at epoch: 21
# epoch 21 train loss: 0.7075357608672352 validation loss: 0.8740781545639038
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2770 | 0.3031 | 0.6659 | 0.4589
# Early stopping at epoch: 23
# epoch 23 train loss: 0.6883946657180786 validation loss: 0.920829713344574
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2481 | 0.2585 | 0.6798 | 0.4583
# -------Target city: BOULDER--------
# (342, 6) (342, 3)
# Early stopping at epoch: 284
# epoch 284 train loss: 0.4945363825589075 validation loss: 0.37254995107650757
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9718 | 1.9204 | 0.3970 | 0.2272
# Early stopping at epoch: 20
# epoch 20 train loss: 0.5895354747772217 validation loss: 0.5223210453987122
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9661 | 1.9059 | 0.3968 | 0.2275
# -------Target city: Auchterarder--------
# (18, 6) (18, 3)
# Early stopping at epoch: 24
# epoch 24 train loss: 0.4405783414840698 validation loss: 1.0424243211746216
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# Early stopping at epoch: 137
# epoch 137 train loss: 0.6503259539604187 validation loss: 0.9511966109275818
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# -------Target city: Kinross--------
# (144, 6) (144, 3)
# Early stopping at epoch: 20
# epoch 20 train loss: 0.8631656765937805 validation loss: 1.2207051515579224
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.6509 | 0.4361
# Early stopping at epoch: 20
# epoch 20 train loss: 1.0370163917541504 validation loss: 1.0242972373962402
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5972 | 1.1774 | 0.6974 | 0.5040
# -------Target city: Pitlochry--------
# (54, 6) (54, 3)
# Early stopping at epoch: 43
# epoch 43 train loss: 0.38925114274024963 validation loss: 0.4369642734527588
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# Early stopping at epoch: 67
# epoch 67 train loss: 0.11719172447919846 validation loss: 0.009348486550152302
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# -------Target city: Crieff--------
# (36, 6) (36, 3)
# Early stopping at epoch: 53
# epoch 53 train loss: 0.4126325249671936 validation loss: 0.5672949552536011
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# Early stopping at epoch: 20
# epoch 20 train loss: 0.34756022691726685 validation loss: 0.3457834720611572
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# -------Target city: Aberfeldy--------
# (36, 6) (36, 3)
# Early stopping at epoch: 60
# epoch 60 train loss: 0.31614333391189575 validation loss: 0.21372319757938385
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# Early stopping at epoch: 21
# epoch 21 train loss: 0.8071669936180115 validation loss: 0.21347853541374207
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# -------Target city: Dunkeld--------
# (18, 6) (18, 3)
# Early stopping at epoch: 217
# epoch 217 train loss: 0.5925036668777466 validation loss: 0.007621997036039829
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# Early stopping at epoch: 107
# epoch 107 train loss: 0.5656859278678894 validation loss: 0.0162369217723608
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# -------Target city: Blairgowrie--------
# (18, 6) (18, 3)
# Early stopping at epoch: 251
# epoch 251 train loss: 0.5907113552093506 validation loss: 1.0527186393737793
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5833 | 1.1667 | 0.5307 | 0.2817
# Early stopping at epoch: 26
# epoch 26 train loss: 0.6941306591033936 validation loss: 1.6366758346557617
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.5814 | 0.3380
# -------------------------------
# -------Source city: HK-------
# -------------------------------
# (6060, 6) (6060, 3)
# Early stopping at epoch: 195
# epoch 195 train loss: 0.6849166662386148 validation loss: 0.7260994446946449
# Test MAPE1: SMAPE: RMSE:  MAE: | 0.1934 | 0.1994 | 0.8278 | 0.5311
# -------Target city: Perth--------
# (108, 6) (108, 3)
# Early stopping at epoch: 38
# epoch 38 train loss: 0.4840872883796692 validation loss: 0.7390336394309998
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2726 | 0.3715 | 0.7869 | 0.4714
# Early stopping at epoch: 41
# epoch 41 train loss: 0.7003467679023743 validation loss: 0.34898677468299866
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2731 | 0.3775 | 0.7863 | 0.4677
# -------Target city: PALO--------
# (126, 6) (126, 3)
# Early stopping at epoch: 54
# epoch 54 train loss: 0.6426924467086792 validation loss: 1.0671933889389038
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8008 | 1.5479 | 1.0693 | 0.6755
# Early stopping at epoch: 45
# epoch 45 train loss: 0.6855440735816956 validation loss: 0.5802767276763916
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.4334 | 0.6583 | 1.0091 | 0.8080
# -------Target city: DUNDEE--------
# (486, 6) (486, 3)
# Early stopping at epoch: 23
# epoch 23 train loss: 0.6489854619190647 validation loss: 0.8838788270950317
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2250 | 0.2231 | 0.6507 | 0.4248
# Early stopping at epoch: 23
# epoch 23 train loss: 0.6883946657180786 validation loss: 0.920829713344574
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2481 | 0.2585 | 0.6798 | 0.4583
# -------Target city: BOULDER--------
# (342, 6) (342, 3)
# Early stopping at epoch: 333
# epoch 333 train loss: 0.4878239971900104 validation loss: 0.36564934253692627
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9718 | 1.9204 | 0.3970 | 0.2272
# Early stopping at epoch: 20
# epoch 20 train loss: 0.5895354747772217 validation loss: 0.5223210453987122
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9661 | 1.9059 | 0.3968 | 0.2275
# -------Target city: Auchterarder--------
# (18, 6) (18, 3)
# Early stopping at epoch: 139
# epoch 139 train loss: 0.42850008606910706 validation loss: 1.0397588014602661
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# Early stopping at epoch: 137
# epoch 137 train loss: 0.6503259539604187 validation loss: 0.951196551322937
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# -------Target city: Kinross--------
# (144, 6) (144, 3)
# Early stopping at epoch: 20
# epoch 20 train loss: 0.8655362725257874 validation loss: 1.2114477157592773
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.6509 | 0.4361
# Early stopping at epoch: 20
# epoch 20 train loss: 1.0370163917541504 validation loss: 1.0242972373962402
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5972 | 1.1774 | 0.6974 | 0.5040
# -------Target city: Pitlochry--------
# (54, 6) (54, 3)
# Early stopping at epoch: 54
# epoch 54 train loss: 0.3819825351238251 validation loss: 0.42561930418014526
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# Early stopping at epoch: 67
# epoch 67 train loss: 0.11719173192977905 validation loss: 0.009348485618829727
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# -------Target city: Crieff--------
# (36, 6) (36, 3)
# Early stopping at epoch: 155
# epoch 155 train loss: 0.4105127453804016 validation loss: 0.5306548476219177
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# Early stopping at epoch: 20
# epoch 20 train loss: 0.34756022691726685 validation loss: 0.3457834720611572
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# -------Target city: Aberfeldy--------
# (36, 6) (36, 3)
# Early stopping at epoch: 63
# epoch 63 train loss: 0.31547117233276367 validation loss: 0.2132478505373001
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# Early stopping at epoch: 21
# epoch 21 train loss: 0.8071669936180115 validation loss: 0.21347853541374207
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# -------Target city: Dunkeld--------
# (18, 6) (18, 3)
# Early stopping at epoch: 198
# epoch 198 train loss: 0.5889992713928223 validation loss: 0.0013492227299138904
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# Early stopping at epoch: 107
# epoch 107 train loss: 0.5656859278678894 validation loss: 0.0162369217723608
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# -------Target city: Blairgowrie--------
# (18, 6) (18, 3)
# Early stopping at epoch: 235
# epoch 235 train loss: 0.5885002017021179 validation loss: 1.0521838665008545
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5833 | 1.1667 | 0.5307 | 0.2817
# Early stopping at epoch: 26
# epoch 26 train loss: 0.6941306591033936 validation loss: 1.6366758346557617
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.5814 | 0.3380
# -------------------------------
# -------Source city: PALO-------
# -------------------------------
# (3976, 6) (3976, 3)
# Early stopping at epoch: 31
# epoch 31 train loss: 0.7819604592503242 validation loss: 0.7607690691947937
# Test MAPE1: SMAPE: RMSE:  MAE: | 0.6102 | 1.0619 | 1.0387 | 0.7715
# -------Target city: Perth--------
# (108, 6) (108, 3)
# Early stopping at epoch: 247
# epoch 247 train loss: 0.45527148246765137 validation loss: 0.7481308579444885
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2832 | 0.4096 | 0.8399 | 0.4819
# Early stopping at epoch: 41
# epoch 41 train loss: 0.7003467082977295 validation loss: 0.34898677468299866
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2731 | 0.3775 | 0.7863 | 0.4677
# -------Target city: HK--------
# (180, 6) (180, 3)
# Early stopping at epoch: 76
# epoch 76 train loss: 0.8738831849823221 validation loss: 0.5554999113082886
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2226 | 0.2404 | 0.7742 | 0.5403
# Early stopping at epoch: 24
# epoch 24 train loss: 0.8132674098014832 validation loss: 0.9421013593673706
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3196 | 0.4577 | 0.7618 | 0.5827
# -------Target city: DUNDEE--------
# (486, 6) (486, 3)
# Early stopping at epoch: 27
# epoch 27 train loss: 0.6778069578386501 validation loss: 0.9088940024375916
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2282 | 0.2253 | 0.6514 | 0.4320
# Early stopping at epoch: 23
# epoch 23 train loss: 0.6883946657180786 validation loss: 0.920829713344574
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2481 | 0.2585 | 0.6798 | 0.4583
# -------Target city: BOULDER--------
# (342, 6) (342, 3)
# Early stopping at epoch: 102
# epoch 102 train loss: 0.5012883832662856 validation loss: 0.37518343329429626
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9718 | 1.9204 | 0.3970 | 0.2272
# Early stopping at epoch: 20
# epoch 20 train loss: 0.5895354747772217 validation loss: 0.5223211050033569
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9661 | 1.9059 | 0.3968 | 0.2275
# -------Target city: Auchterarder--------
# (18, 6) (18, 3)
# Early stopping at epoch: 56
# epoch 56 train loss: 0.43202102184295654 validation loss: 1.0384254455566406
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# Early stopping at epoch: 137
# epoch 137 train loss: 0.6503259539604187 validation loss: 0.951196551322937
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# -------Target city: Kinross--------
# (144, 6) (144, 3)
# Early stopping at epoch: 20
# epoch 20 train loss: 0.8642261624336243 validation loss: 1.2167450189590454
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.6509 | 0.4361
# Early stopping at epoch: 20
# epoch 20 train loss: 1.0370163917541504 validation loss: 1.0242972373962402
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5972 | 1.1774 | 0.6974 | 0.5040
# -------Target city: Pitlochry--------
# (54, 6) (54, 3)
# Early stopping at epoch: 70
# epoch 70 train loss: 0.3775761127471924 validation loss: 0.4282689690589905
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# Early stopping at epoch: 67
# epoch 67 train loss: 0.11719171702861786 validation loss: 0.009348486550152302
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# -------Target city: Crieff--------
# (36, 6) (36, 3)
# Early stopping at epoch: 131
# epoch 131 train loss: 0.40794432163238525 validation loss: 0.5585485100746155
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# Early stopping at epoch: 20
# epoch 20 train loss: 0.34756022691726685 validation loss: 0.3457834720611572
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# -------Target city: Aberfeldy--------
# (36, 6) (36, 3)
# Early stopping at epoch: 33
# epoch 33 train loss: 0.3202756345272064 validation loss: 0.2102469950914383
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# Early stopping at epoch: 21
# epoch 21 train loss: 0.8071669936180115 validation loss: 0.21347853541374207
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# -------Target city: Dunkeld--------
# (18, 6) (18, 3)
# Early stopping at epoch: 180
# epoch 180 train loss: 0.5912224054336548 validation loss: 0.007580000441521406
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# Early stopping at epoch: 107
# epoch 107 train loss: 0.5656859278678894 validation loss: 0.016236931085586548
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# -------Target city: Blairgowrie--------
# (18, 6) (18, 3)
# Early stopping at epoch: 294
# epoch 294 train loss: 0.5864337086677551 validation loss: 1.0556461811065674
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5833 | 1.1667 | 0.5307 | 0.2817
# Early stopping at epoch: 26
# epoch 26 train loss: 0.6941306591033936 validation loss: 1.6366758346557617
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.5814 | 0.3380
# -------------------------------
# -------Source city: DUNDEE-------
# -------------------------------
# (15849, 6) (15849, 3)
# Early stopping at epoch: 92
# epoch 92 train loss: 0.5912234805502606 validation loss: 0.556836980412059
# Test MAPE1: SMAPE: RMSE:  MAE: | 0.2511 | 0.2996 | 0.6921 | 0.4399
# -------Target city: Perth--------
# (108, 6) (108, 3)
# Early stopping at epoch: 92
# epoch 92 train loss: 0.4888208210468292 validation loss: 0.7455731630325317
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2717 | 0.3647 | 0.7804 | 0.4731
# Early stopping at epoch: 41
# epoch 41 train loss: 0.7003467679023743 validation loss: 0.34898677468299866
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2731 | 0.3775 | 0.7863 | 0.4677
# -------Target city: HK--------
# (180, 6) (180, 3)
# Early stopping at epoch: 86
# epoch 86 train loss: 0.8470398128381249 validation loss: 0.574557363986969
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2287 | 0.2545 | 0.7767 | 0.5286
# Early stopping at epoch: 24
# epoch 24 train loss: 0.8132673501968384 validation loss: 0.9421012997627258
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3196 | 0.4577 | 0.7618 | 0.5827
# -------Target city: PALO--------
# (126, 6) (126, 3)
# Early stopping at epoch: 64
# epoch 64 train loss: 0.6722143292427063 validation loss: 1.0603996515274048
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.7711 | 1.4506 | 1.0339 | 0.6845
# Early stopping at epoch: 45
# epoch 45 train loss: 0.6855440139770508 validation loss: 0.5802768468856812
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.4334 | 0.6583 | 1.0091 | 0.8080
# -------Target city: BOULDER--------
# (342, 6) (342, 3)
# Early stopping at epoch: 161
# epoch 161 train loss: 0.47605339964296317 validation loss: 0.36564046144485474
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9718 | 1.9204 | 0.3970 | 0.2272
# Early stopping at epoch: 20
# epoch 20 train loss: 0.5895354747772217 validation loss: 0.5223210453987122
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9661 | 1.9059 | 0.3968 | 0.2275
# -------Target city: Auchterarder--------
# (18, 6) (18, 3)
# Early stopping at epoch: 48
# epoch 48 train loss: 0.4355084300041199 validation loss: 1.0401479005813599
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# Early stopping at epoch: 137
# epoch 137 train loss: 0.6503259539604187 validation loss: 0.9511966109275818
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# -------Target city: Kinross--------
# (144, 6) (144, 3)
# Early stopping at epoch: 20
# epoch 20 train loss: 0.8684020638465881 validation loss: 1.2198723554611206
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.6509 | 0.4361
# Early stopping at epoch: 20
# epoch 20 train loss: 1.0370163917541504 validation loss: 1.0242972373962402
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5972 | 1.1774 | 0.6974 | 0.5040
# -------Target city: Pitlochry--------
# (54, 6) (54, 3)
# Early stopping at epoch: 46
# epoch 46 train loss: 0.3890891671180725 validation loss: 0.43150410056114197
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# Early stopping at epoch: 67
# epoch 67 train loss: 0.11719172447919846 validation loss: 0.009348484687507153
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# -------Target city: Crieff--------
# (36, 6) (36, 3)
# Early stopping at epoch: 148
# epoch 148 train loss: 0.4118582308292389 validation loss: 0.5314106345176697
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# Early stopping at epoch: 20
# epoch 20 train loss: 0.34756025671958923 validation loss: 0.3457834720611572
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# -------Target city: Aberfeldy--------
# (36, 6) (36, 3)
# Early stopping at epoch: 64
# epoch 64 train loss: 0.3155597150325775 validation loss: 0.2135964334011078
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# Early stopping at epoch: 21
# epoch 21 train loss: 0.8071669936180115 validation loss: 0.21347853541374207
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# -------Target city: Dunkeld--------
# (18, 6) (18, 3)
# Early stopping at epoch: 164
# epoch 164 train loss: 0.5896501541137695 validation loss: 0.006861909292638302
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# Early stopping at epoch: 107
# epoch 107 train loss: 0.5656859278678894 validation loss: 0.016236931085586548
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# -------Target city: Blairgowrie--------
# (18, 6) (18, 3)
# Early stopping at epoch: 234
# epoch 234 train loss: 0.5883837342262268 validation loss: 1.056535243988037
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5833 | 1.1667 | 0.5307 | 0.2817
# Early stopping at epoch: 26
# epoch 26 train loss: 0.6941306591033936 validation loss: 1.6366758346557617
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.5814 | 0.3380
# -------------------------------
# -------Source city: BOULDER-------
# -------------------------------
# (10792, 6) (10792, 3)
# Early stopping at epoch: 94
# epoch 94 train loss: 0.5355567835952293 validation loss: 0.5903389570943842
# Test MAPE1: SMAPE: RMSE:  MAE: | 0.9718 | 1.9204 | 0.3970 | 0.2272
# -------Target city: Perth--------
# (108, 6) (108, 3)
# Early stopping at epoch: 53
# epoch 53 train loss: 0.46646401286125183 validation loss: 0.7361379861831665
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2778 | 0.3941 | 0.8126 | 0.4714
# Early stopping at epoch: 41
# epoch 41 train loss: 0.7003467679023743 validation loss: 0.34898677468299866
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2731 | 0.3775 | 0.7863 | 0.4677
# -------Target city: HK--------
# (180, 6) (180, 3)
# Early stopping at epoch: 62
# epoch 62 train loss: 0.8595040346446791 validation loss: 0.5462169051170349
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2306 | 0.2541 | 0.7716 | 0.5395
# Early stopping at epoch: 24
# epoch 24 train loss: 0.8132673501968384 validation loss: 0.9421012997627258
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3196 | 0.4577 | 0.7618 | 0.5827
# -------Target city: PALO--------
# (126, 6) (126, 3)
# Early stopping at epoch: 34
# epoch 34 train loss: 0.6858106851577759 validation loss: 1.0358986854553223
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.7789 | 1.4677 | 1.0453 | 0.6932
# Early stopping at epoch: 45
# epoch 45 train loss: 0.6855440139770508 validation loss: 0.5802768468856812
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.4334 | 0.6583 | 1.0091 | 0.8080
# -------Target city: DUNDEE--------
# (486, 6) (486, 3)
# Early stopping at epoch: 63
# epoch 63 train loss: 0.610715440713278 validation loss: 0.8456841707229614
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2272 | 0.2417 | 0.6496 | 0.4235
# Early stopping at epoch: 23
# epoch 23 train loss: 0.6883946657180786 validation loss: 0.920829713344574
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2481 | 0.2585 | 0.6798 | 0.4583
# -------Target city: Auchterarder--------
# (18, 6) (18, 3)
# Early stopping at epoch: 40
# epoch 40 train loss: 0.43591976165771484 validation loss: 1.0336414575576782
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# Early stopping at epoch: 137
# epoch 137 train loss: 0.6503259539604187 validation loss: 0.9511966109275818
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# -------Target city: Kinross--------
# (144, 6) (144, 3)
# Early stopping at epoch: 20
# epoch 20 train loss: 0.8710695505142212 validation loss: 1.2174084186553955
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.6509 | 0.4361
# Early stopping at epoch: 20
# epoch 20 train loss: 1.0370163917541504 validation loss: 1.0242972373962402
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5972 | 1.1774 | 0.6974 | 0.5040
# -------Target city: Pitlochry--------
# (54, 6) (54, 3)
# Early stopping at epoch: 83
# epoch 83 train loss: 0.3858027458190918 validation loss: 0.44194528460502625
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# Early stopping at epoch: 67
# epoch 67 train loss: 0.11719172447919846 validation loss: 0.009348484687507153
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# -------Target city: Crieff--------
# (36, 6) (36, 3)
# Early stopping at epoch: 54
# epoch 54 train loss: 0.4157427251338959 validation loss: 0.5768720507621765
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# Early stopping at epoch: 20
# epoch 20 train loss: 0.34756025671958923 validation loss: 0.3457834720611572
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# -------Target city: Aberfeldy--------
# (36, 6) (36, 3)
# Early stopping at epoch: 30
# epoch 30 train loss: 0.3191213309764862 validation loss: 0.21365779638290405
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# Early stopping at epoch: 21
# epoch 21 train loss: 0.8071669936180115 validation loss: 0.21347853541374207
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# -------Target city: Dunkeld--------
# (18, 6) (18, 3)
# Early stopping at epoch: 454
# epoch 454 train loss: 0.5879537463188171 validation loss: 0.002716940129175782
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# Early stopping at epoch: 107
# epoch 107 train loss: 0.5656859278678894 validation loss: 0.016236931085586548
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# -------Target city: Blairgowrie--------
# (18, 6) (18, 3)
# Early stopping at epoch: 423
# epoch 423 train loss: 0.5869496464729309 validation loss: 1.05677330493927
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5833 | 1.1667 | 0.5307 | 0.2817
# Early stopping at epoch: 26
# epoch 26 train loss: 0.6941306591033936 validation loss: 1.6366758346557617
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.5814 | 0.3380
# -------------------------------
# -------Source city: Auchterarder-------
# -------------------------------
# (568, 6) (568, 3)
# Early stopping at epoch: 38
# epoch 38 train loss: 0.6388577222824097 validation loss: 0.6975092887878418
# Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# -------Target city: Perth--------
# (108, 6) (108, 3)
# Early stopping at epoch: 121
# epoch 121 train loss: 0.4558028280735016 validation loss: 0.745405375957489
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2825 | 0.4091 | 0.8395 | 0.4812
# Early stopping at epoch: 41
# epoch 41 train loss: 0.7003467679023743 validation loss: 0.34898677468299866
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2731 | 0.3775 | 0.7863 | 0.4677
# -------Target city: HK--------
# (180, 6) (180, 3)
# Early stopping at epoch: 47
# epoch 47 train loss: 0.8811703129121434 validation loss: 0.5290402173995972
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2205 | 0.2271 | 0.7931 | 0.5440
# Early stopping at epoch: 24
# epoch 24 train loss: 0.8132673501968384 validation loss: 0.9421012997627258
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3196 | 0.4577 | 0.7618 | 0.5827
# -------Target city: PALO--------
# (126, 6) (126, 3)
# Early stopping at epoch: 22
# epoch 22 train loss: 0.6968393921852112 validation loss: 1.1635297536849976
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9970 | 1.9926 | 1.1255 | 0.6848
# Early stopping at epoch: 45
# epoch 45 train loss: 0.6855440139770508 validation loss: 0.5802768468856812
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.4334 | 0.6583 | 1.0091 | 0.8080
# -------Target city: DUNDEE--------
# (486, 6) (486, 3)
# Early stopping at epoch: 23
# epoch 23 train loss: 0.7076701096698125 validation loss: 0.8805410265922546
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2740 | 0.2979 | 0.6654 | 0.4589
# Early stopping at epoch: 23
# epoch 23 train loss: 0.6883946657180786 validation loss: 0.920829713344574
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2481 | 0.2585 | 0.6798 | 0.4583
# -------Target city: BOULDER--------
# (342, 6) (342, 3)
# Early stopping at epoch: 235
# epoch 235 train loss: 0.4940313716500359 validation loss: 0.37241461873054504
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9718 | 1.9204 | 0.3970 | 0.2272
# Early stopping at epoch: 20
# epoch 20 train loss: 0.5895354747772217 validation loss: 0.5223210453987122
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9661 | 1.9059 | 0.3968 | 0.2275
# -------Target city: Kinross--------
# (144, 6) (144, 3)
# Early stopping at epoch: 20
# epoch 20 train loss: 0.8696110844612122 validation loss: 1.2104498147964478
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.6509 | 0.4361
# Early stopping at epoch: 20
# epoch 20 train loss: 1.0370163917541504 validation loss: 1.0242972373962402
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5972 | 1.1774 | 0.6974 | 0.5040
# -------Target city: Pitlochry--------
# (54, 6) (54, 3)
# Early stopping at epoch: 95
# epoch 95 train loss: 0.3790483772754669 validation loss: 0.42104771733283997
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# Early stopping at epoch: 67
# epoch 67 train loss: 0.11719172447919846 validation loss: 0.009348484687507153
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# -------Target city: Crieff--------
# (36, 6) (36, 3)
# Early stopping at epoch: 120
# epoch 120 train loss: 0.4127393960952759 validation loss: 0.5327394604682922
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# Early stopping at epoch: 20
# epoch 20 train loss: 0.34756025671958923 validation loss: 0.3457834720611572
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# -------Target city: Aberfeldy--------
# (36, 6) (36, 3)
# Early stopping at epoch: 48
# epoch 48 train loss: 0.3160525858402252 validation loss: 0.21070857346057892
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# Early stopping at epoch: 21
# epoch 21 train loss: 0.8071669936180115 validation loss: 0.21347853541374207
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# -------Target city: Dunkeld--------
# (18, 6) (18, 3)
# Early stopping at epoch: 203
# epoch 203 train loss: 0.5884070992469788 validation loss: 0.004866286180913448
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# Early stopping at epoch: 107
# epoch 107 train loss: 0.5656859278678894 validation loss: 0.016236931085586548
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# -------Target city: Blairgowrie--------
# (18, 6) (18, 3)
# Early stopping at epoch: 37
# epoch 37 train loss: 0.601087749004364 validation loss: 1.0979022979736328
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.7639 | 1.5278 | 0.5395 | 0.2911
# Early stopping at epoch: 26
# epoch 26 train loss: 0.6941306591033936 validation loss: 1.6366758346557617
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.5814 | 0.3380
# -------------------------------
# -------Source city: Kinross-------
# -------------------------------
# (4544, 6) (4544, 3)
# Early stopping at epoch: 35
# epoch 35 train loss: 0.7242688538611673 validation loss: 0.7024791836738586
# Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.6509 | 0.4361
# -------Target city: Perth--------
# (108, 6) (108, 3)
# Early stopping at epoch: 81
# epoch 81 train loss: 0.45503103733062744 validation loss: 0.7427352666854858
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2824 | 0.4091 | 0.8395 | 0.4811
# Early stopping at epoch: 41
# epoch 41 train loss: 0.7003467679023743 validation loss: 0.34898677468299866
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2731 | 0.3775 | 0.7863 | 0.4677
# -------Target city: HK--------
# (180, 6) (180, 3)
# Early stopping at epoch: 52
# epoch 52 train loss: 0.8852615572555721 validation loss: 0.5155958533287048
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2234 | 0.2306 | 0.7900 | 0.5443
# Early stopping at epoch: 24
# epoch 24 train loss: 0.8132673501968384 validation loss: 0.9421012997627258
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3196 | 0.4577 | 0.7618 | 0.5827
# -------Target city: PALO--------
# (126, 6) (126, 3)
# Early stopping at epoch: 21
# epoch 21 train loss: 0.6818815469741821 validation loss: 1.14653480052948
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 1.1254 | 0.6829
# Early stopping at epoch: 45
# epoch 45 train loss: 0.6855440139770508 validation loss: 0.5802768468856812
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.4334 | 0.6583 | 1.0091 | 0.8080
# -------Target city: DUNDEE--------
# (486, 6) (486, 3)
# Early stopping at epoch: 22
# epoch 22 train loss: 0.7080012003224748 validation loss: 0.8724066615104675
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2738 | 0.3018 | 0.6678 | 0.4624
# Early stopping at epoch: 23
# epoch 23 train loss: 0.6883946657180786 validation loss: 0.920829713344574
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2481 | 0.2585 | 0.6798 | 0.4583
# -------Target city: BOULDER--------
# (342, 6) (342, 3)
# Early stopping at epoch: 26
# epoch 26 train loss: 0.5168553099797232 validation loss: 0.39703917503356934
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9718 | 1.9204 | 0.3970 | 0.2272
# Early stopping at epoch: 20
# epoch 20 train loss: 0.5895354747772217 validation loss: 0.5223210453987122
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9661 | 1.9059 | 0.3968 | 0.2275
# -------Target city: Auchterarder--------
# (18, 6) (18, 3)
# Early stopping at epoch: 37
# epoch 37 train loss: 0.4320569336414337 validation loss: 1.056813359260559
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# Early stopping at epoch: 137
# epoch 137 train loss: 0.6503259539604187 validation loss: 0.9511966109275818
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# -------Target city: Pitlochry--------
# (54, 6) (54, 3)
# Early stopping at epoch: 81
# epoch 81 train loss: 0.37609025835990906 validation loss: 0.42037704586982727
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# Early stopping at epoch: 67
# epoch 67 train loss: 0.11719172447919846 validation loss: 0.009348484687507153
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# -------Target city: Crieff--------
# (36, 6) (36, 3)
# Early stopping at epoch: 181
# epoch 181 train loss: 0.41080018877983093 validation loss: 0.5219724774360657
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# Early stopping at epoch: 20
# epoch 20 train loss: 0.34756025671958923 validation loss: 0.3457834720611572
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# -------Target city: Aberfeldy--------
# (36, 6) (36, 3)
# Early stopping at epoch: 47
# epoch 47 train loss: 0.3192286491394043 validation loss: 0.21081025898456573
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# Early stopping at epoch: 21
# epoch 21 train loss: 0.8071669936180115 validation loss: 0.21347853541374207
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# -------Target city: Dunkeld--------
# (18, 6) (18, 3)
# Early stopping at epoch: 198
# epoch 198 train loss: 0.6219128370285034 validation loss: 0.0025689073372632265
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4893 | 0.2394
# Early stopping at epoch: 107
# epoch 107 train loss: 0.5656859278678894 validation loss: 0.016236931085586548
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# -------Target city: Blairgowrie--------
# (18, 6) (18, 3)
# Early stopping at epoch: 308
# epoch 308 train loss: 0.5991688370704651 validation loss: 1.0873581171035767
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.7639 | 1.5278 | 0.5395 | 0.2911
# Early stopping at epoch: 26
# epoch 26 train loss: 0.6941306591033936 validation loss: 1.6366758346557617
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.5814 | 0.3380
# -------------------------------
# -------Source city: Pitlochry-------
# -------------------------------
# (1704, 6) (1704, 3)
# Early stopping at epoch: 43
# epoch 43 train loss: 0.40774985163944744 validation loss: 0.2832372188568115
# Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# -------Target city: Perth--------
# (108, 6) (108, 3)
# Early stopping at epoch: 39
# epoch 39 train loss: 0.4770186245441437 validation loss: 0.7716462016105652
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2810 | 0.4015 | 0.8280 | 0.4785
# Early stopping at epoch: 41
# epoch 41 train loss: 0.7003467679023743 validation loss: 0.34898677468299866
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2731 | 0.3775 | 0.7863 | 0.4677
# -------Target city: HK--------
# (180, 6) (180, 3)
# Early stopping at epoch: 47
# epoch 47 train loss: 0.8861285831496032 validation loss: 0.5262417793273926
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2233 | 0.2307 | 0.7916 | 0.5440
# Early stopping at epoch: 24
# epoch 24 train loss: 0.8132673501968384 validation loss: 0.9421012997627258
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3196 | 0.4577 | 0.7618 | 0.5827
# -------Target city: PALO--------
# (126, 6) (126, 3)
# Early stopping at epoch: 24
# epoch 24 train loss: 0.7574537992477417 validation loss: 1.0653021335601807
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.6698 | 1.2116 | 1.0405 | 0.7461
# Early stopping at epoch: 45
# epoch 45 train loss: 0.6855440139770508 validation loss: 0.5802768468856812
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.4334 | 0.6583 | 1.0091 | 0.8080
# -------Target city: DUNDEE--------
# (486, 6) (486, 3)
# Early stopping at epoch: 72
# epoch 72 train loss: 0.7068712310855092 validation loss: 0.8709322214126587
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2738 | 0.3019 | 0.6669 | 0.4609
# Early stopping at epoch: 23
# epoch 23 train loss: 0.6883946657180786 validation loss: 0.920829713344574
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2481 | 0.2585 | 0.6798 | 0.4583
# -------Target city: BOULDER--------
# (342, 6) (342, 3)
# Early stopping at epoch: 238
# epoch 238 train loss: 0.49701802562646064 validation loss: 0.3728841245174408
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9718 | 1.9204 | 0.3970 | 0.2272
# Early stopping at epoch: 20
# epoch 20 train loss: 0.5895354747772217 validation loss: 0.5223210453987122
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9661 | 1.9059 | 0.3968 | 0.2275
# -------Target city: Auchterarder--------
# (18, 6) (18, 3)
# Early stopping at epoch: 27
# epoch 27 train loss: 0.4407949447631836 validation loss: 1.0469679832458496
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# Early stopping at epoch: 137
# epoch 137 train loss: 0.6503259539604187 validation loss: 0.9511966109275818
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# -------Target city: Kinross--------
# (144, 6) (144, 3)
# Early stopping at epoch: 20
# epoch 20 train loss: 0.8643893599510193 validation loss: 1.2154639959335327
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.6509 | 0.4361
# Early stopping at epoch: 20
# epoch 20 train loss: 1.0370163917541504 validation loss: 1.0242972373962402
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5972 | 1.1774 | 0.6974 | 0.5040
# -------Target city: Crieff--------
# (36, 6) (36, 3)
# Early stopping at epoch: 374
# epoch 374 train loss: 0.4116484820842743 validation loss: 0.5407643914222717
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# Early stopping at epoch: 20
# epoch 20 train loss: 0.34756025671958923 validation loss: 0.3457834720611572
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# -------Target city: Aberfeldy--------
# (36, 6) (36, 3)
# Early stopping at epoch: 36
# epoch 36 train loss: 0.31942272186279297 validation loss: 0.20956039428710938
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# Early stopping at epoch: 21
# epoch 21 train loss: 0.8071669936180115 validation loss: 0.21347853541374207
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# -------Target city: Dunkeld--------
# (18, 6) (18, 3)
# Early stopping at epoch: 199
# epoch 199 train loss: 0.6041511297225952 validation loss: 0.013118439354002476
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# Early stopping at epoch: 107
# epoch 107 train loss: 0.5656859278678894 validation loss: 0.0162369217723608
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# -------Target city: Blairgowrie--------
# (18, 6) (18, 3)
# Early stopping at epoch: 325
# epoch 325 train loss: 0.5913113355636597 validation loss: 1.0579205751419067
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5833 | 1.1667 | 0.5307 | 0.2817
# Early stopping at epoch: 26
# epoch 26 train loss: 0.6941306591033936 validation loss: 1.6366758346557617
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.5814 | 0.3380
# -------------------------------
# -------Source city: Crieff-------
# -------------------------------
# (1136, 6) (1136, 3)
# Early stopping at epoch: 44
# epoch 44 train loss: 0.6807858347892761 validation loss: 0.3940282464027405
# Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# -------Target city: Perth--------
# (108, 6) (108, 3)
# Early stopping at epoch: 26
# epoch 26 train loss: 0.48226553201675415 validation loss: 0.7392123937606812
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2715 | 0.3755 | 0.7821 | 0.4627
# Early stopping at epoch: 41
# epoch 41 train loss: 0.7003467679023743 validation loss: 0.34898677468299866
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2731 | 0.3775 | 0.7863 | 0.4677
# -------Target city: HK--------
# (180, 6) (180, 3)
# Early stopping at epoch: 36
# epoch 36 train loss: 0.8823310572501512 validation loss: 0.5402743816375732
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2226 | 0.2390 | 0.7812 | 0.5402
# Early stopping at epoch: 24
# epoch 24 train loss: 0.8132673501968384 validation loss: 0.9421012997627258
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3196 | 0.4577 | 0.7618 | 0.5827
# -------Target city: PALO--------
# (126, 6) (126, 3)
# Early stopping at epoch: 21
# epoch 21 train loss: 0.6692392826080322 validation loss: 1.1312865018844604
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9205 | 1.8085 | 1.1027 | 0.6981
# Early stopping at epoch: 45
# epoch 45 train loss: 0.6855440139770508 validation loss: 0.5802768468856812
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.4334 | 0.6583 | 1.0091 | 0.8080
# -------Target city: DUNDEE--------
# (486, 6) (486, 3)
# Early stopping at epoch: 61
# epoch 61 train loss: 0.7062103154944946 validation loss: 0.8715707659721375
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2766 | 0.3031 | 0.6671 | 0.4613
# Early stopping at epoch: 23
# epoch 23 train loss: 0.6883946657180786 validation loss: 0.920829713344574
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2481 | 0.2585 | 0.6798 | 0.4583
# -------Target city: BOULDER--------
# (342, 6) (342, 3)
# Early stopping at epoch: 136
# epoch 136 train loss: 0.5020655355795212 validation loss: 0.3791002333164215
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9718 | 1.9204 | 0.3970 | 0.2272
# Early stopping at epoch: 20
# epoch 20 train loss: 0.5895354747772217 validation loss: 0.5223210453987122
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9661 | 1.9059 | 0.3968 | 0.2275
# -------Target city: Auchterarder--------
# (18, 6) (18, 3)
# Early stopping at epoch: 97
# epoch 97 train loss: 0.43244442343711853 validation loss: 1.0464998483657837
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# Early stopping at epoch: 137
# epoch 137 train loss: 0.6503259539604187 validation loss: 0.9511966109275818
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# -------Target city: Kinross--------
# (144, 6) (144, 3)
# Early stopping at epoch: 25
# epoch 25 train loss: 0.8639551401138306 validation loss: 1.2156610488891602
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.6509 | 0.4361
# Early stopping at epoch: 20
# epoch 20 train loss: 1.0370163917541504 validation loss: 1.0242972373962402
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5972 | 1.1774 | 0.6974 | 0.5040
# -------Target city: Pitlochry--------
# (54, 6) (54, 3)
# Early stopping at epoch: 120
# epoch 120 train loss: 0.3775102496147156 validation loss: 0.42873430252075195
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# Early stopping at epoch: 67
# epoch 67 train loss: 0.11719172447919846 validation loss: 0.009348484687507153
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# -------Target city: Aberfeldy--------
# (36, 6) (36, 3)
# Early stopping at epoch: 27
# epoch 27 train loss: 0.3194373548030853 validation loss: 0.21135558187961578
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# Early stopping at epoch: 21
# epoch 21 train loss: 0.8071669936180115 validation loss: 0.21347853541374207
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# -------Target city: Dunkeld--------
# (18, 6) (18, 3)
# Early stopping at epoch: 304
# epoch 304 train loss: 0.5894864201545715 validation loss: 0.01744200848042965
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# Early stopping at epoch: 107
# epoch 107 train loss: 0.5656859278678894 validation loss: 0.016236931085586548
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# -------Target city: Blairgowrie--------
# (18, 6) (18, 3)
# Early stopping at epoch: 189
# epoch 189 train loss: 0.5920079946517944 validation loss: 1.0657312870025635
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5833 | 1.1667 | 0.5307 | 0.2817
# Early stopping at epoch: 26
# epoch 26 train loss: 0.6941306591033936 validation loss: 1.6366758346557617
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.5814 | 0.3380
# -------------------------------
# -------Source city: Aberfeldy-------
# -------------------------------
# (1136, 6) (1136, 3)
# Early stopping at epoch: 55
# epoch 55 train loss: 0.39272287487983704 validation loss: 0.37042197585105896
# Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# -------Target city: Perth--------
# (108, 6) (108, 3)
# Early stopping at epoch: 22
# epoch 22 train loss: 0.4886148273944855 validation loss: 0.7377419471740723
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2709 | 0.3726 | 0.7786 | 0.4634
# Early stopping at epoch: 41
# epoch 41 train loss: 0.7003467679023743 validation loss: 0.34898677468299866
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2731 | 0.3775 | 0.7863 | 0.4677
# -------Target city: HK--------
# (180, 6) (180, 3)
# Early stopping at epoch: 47
# epoch 47 train loss: 0.881894164266642 validation loss: 0.5565055012702942
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2266 | 0.2505 | 0.7786 | 0.5397
# Early stopping at epoch: 24
# epoch 24 train loss: 0.8132673501968384 validation loss: 0.9421012997627258
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3196 | 0.4577 | 0.7618 | 0.5827
# -------Target city: PALO--------
# (126, 6) (126, 3)
# Early stopping at epoch: 21
# epoch 21 train loss: 0.6613336205482483 validation loss: 1.1062638759613037
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9395 | 1.8525 | 1.0990 | 0.6833
# Early stopping at epoch: 45
# epoch 45 train loss: 0.6855440139770508 validation loss: 0.5802768468856812
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.4334 | 0.6583 | 1.0091 | 0.8080
# -------Target city: DUNDEE--------
# (486, 6) (486, 3)
# Early stopping at epoch: 121
# epoch 121 train loss: 0.7060853567262246 validation loss: 0.8689315319061279
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2747 | 0.3024 | 0.6677 | 0.4617
# Early stopping at epoch: 23
# epoch 23 train loss: 0.6883946657180786 validation loss: 0.920829713344574
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2481 | 0.2585 | 0.6798 | 0.4583
# -------Target city: BOULDER--------
# (342, 6) (342, 3)
# Early stopping at epoch: 192
# epoch 192 train loss: 0.5008170371982568 validation loss: 0.37610727548599243
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9718 | 1.9204 | 0.3970 | 0.2272
# Early stopping at epoch: 20
# epoch 20 train loss: 0.5895354747772217 validation loss: 0.5223210453987122
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9661 | 1.9059 | 0.3968 | 0.2275
# -------Target city: Auchterarder--------
# (18, 6) (18, 3)
# Early stopping at epoch: 66
# epoch 66 train loss: 0.4272790849208832 validation loss: 1.053597331047058
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# Early stopping at epoch: 137
# epoch 137 train loss: 0.6503259539604187 validation loss: 0.9511966109275818
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# -------Target city: Kinross--------
# (144, 6) (144, 3)
# Early stopping at epoch: 25
# epoch 25 train loss: 0.8633177280426025 validation loss: 1.2145848274230957
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.6509 | 0.4361
# Early stopping at epoch: 20
# epoch 20 train loss: 1.0370163917541504 validation loss: 1.0242972373962402
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5972 | 1.1774 | 0.6974 | 0.5040
# -------Target city: Pitlochry--------
# (54, 6) (54, 3)
# Early stopping at epoch: 34
# epoch 34 train loss: 0.3986007869243622 validation loss: 0.4412291646003723
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# Early stopping at epoch: 67
# epoch 67 train loss: 0.11719172447919846 validation loss: 0.009348484687507153
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# -------Target city: Crieff--------
# (36, 6) (36, 3)
# Early stopping at epoch: 130
# epoch 130 train loss: 0.41043350100517273 validation loss: 0.5543114542961121
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# Early stopping at epoch: 20
# epoch 20 train loss: 0.34756025671958923 validation loss: 0.3457834720611572
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# -------Target city: Dunkeld--------
# (18, 6) (18, 3)
# Early stopping at epoch: 193
# epoch 193 train loss: 0.5949571132659912 validation loss: 0.025125889107584953
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# Early stopping at epoch: 107
# epoch 107 train loss: 0.5656859278678894 validation loss: 0.016236931085586548
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254
# -------Target city: Blairgowrie--------
# (18, 6) (18, 3)
# Early stopping at epoch: 300
# epoch 300 train loss: 0.5908802151679993 validation loss: 1.0593827962875366
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5833 | 1.1667 | 0.5307 | 0.2817
# Early stopping at epoch: 26
# epoch 26 train loss: 0.6941306591033936 validation loss: 1.6366758346557617
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.5814 | 0.3380
# -------------------------------
# -------Source city: Dunkeld-------
# -------------------------------
# (568, 6) (568, 3)
# Early stopping at epoch: 73
# epoch 73 train loss: 0.600074052810669 validation loss: 0.5579952001571655
# Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4893 | 0.2394
# -------Target city: Perth--------
# (108, 6) (108, 3)
# Early stopping at epoch: 116
# epoch 116 train loss: 0.4557604491710663 validation loss: 0.7462419867515564
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2807 | 0.4069 | 0.8375 | 0.4787
# Early stopping at epoch: 41
# epoch 41 train loss: 0.7003467679023743 validation loss: 0.34898677468299866
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2731 | 0.3775 | 0.7863 | 0.4677
# -------Target city: HK--------
# (180, 6) (180, 3)
# Early stopping at epoch: 37
# epoch 37 train loss: 0.8801589695333737 validation loss: 0.515585720539093
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2195 | 0.2248 | 0.8016 | 0.5454
# Early stopping at epoch: 24
# epoch 24 train loss: 0.8132673501968384 validation loss: 0.9421012997627258
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3196 | 0.4577 | 0.7618 | 0.5827
# -------Target city: PALO--------
# (126, 6) (126, 3)
# Early stopping at epoch: 24
# epoch 24 train loss: 0.7151593565940857 validation loss: 1.087228775024414
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8976 | 1.7557 | 1.0895 | 0.6907
# Early stopping at epoch: 45
# epoch 45 train loss: 0.6855440139770508 validation loss: 0.5802768468856812
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.4334 | 0.6583 | 1.0091 | 0.8080
# -------Target city: DUNDEE--------
# (486, 6) (486, 3)
# Early stopping at epoch: 64
# epoch 64 train loss: 0.673760587130522 validation loss: 0.8916792273521423
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2293 | 0.2205 | 0.6567 | 0.4403
# Early stopping at epoch: 23
# epoch 23 train loss: 0.6883946657180786 validation loss: 0.920829713344574
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2481 | 0.2585 | 0.6798 | 0.4583
# -------Target city: BOULDER--------
# (342, 6) (342, 3)
# Early stopping at epoch: 91
# epoch 91 train loss: 0.5024835896452726 validation loss: 0.3762313425540924
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9718 | 1.9204 | 0.3970 | 0.2272
# Early stopping at epoch: 20
# epoch 20 train loss: 0.5895354747772217 validation loss: 0.5223210453987122
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9661 | 1.9059 | 0.3968 | 0.2275
# -------Target city: Auchterarder--------
# (18, 6) (18, 3)
# Early stopping at epoch: 67
# epoch 67 train loss: 0.43463197350502014 validation loss: 1.03696608543396
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# Early stopping at epoch: 137
# epoch 137 train loss: 0.6503259539604187 validation loss: 0.9511966109275818
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# -------Target city: Kinross--------
# (144, 6) (144, 3)
# Early stopping at epoch: 20
# epoch 20 train loss: 0.8633172512054443 validation loss: 1.2171179056167603
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.6509 | 0.4361
# Early stopping at epoch: 20
# epoch 20 train loss: 1.0370163917541504 validation loss: 1.0242972373962402
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5972 | 1.1774 | 0.6974 | 0.5040
# -------Target city: Pitlochry--------
# (54, 6) (54, 3)
# Early stopping at epoch: 75
# epoch 75 train loss: 0.37941816449165344 validation loss: 0.43024343252182007
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# Early stopping at epoch: 67
# epoch 67 train loss: 0.11719172447919846 validation loss: 0.009348484687507153
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# -------Target city: Crieff--------
# (36, 6) (36, 3)
# Early stopping at epoch: 129
# epoch 129 train loss: 0.41221925616264343 validation loss: 0.538157045841217
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# Early stopping at epoch: 20
# epoch 20 train loss: 0.34756025671958923 validation loss: 0.3457834720611572
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# -------Target city: Aberfeldy--------
# (36, 6) (36, 3)
# Early stopping at epoch: 32
# epoch 32 train loss: 0.3196355104446411 validation loss: 0.21096107363700867
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# Early stopping at epoch: 21
# epoch 21 train loss: 0.8071669936180115 validation loss: 0.21347853541374207
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# -------Target city: Blairgowrie--------
# (18, 6) (18, 3)
# Early stopping at epoch: 20
# epoch 20 train loss: 0.7164649367332458 validation loss: 1.247483491897583
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.5814 | 0.3380
# Early stopping at epoch: 26
# epoch 26 train loss: 0.6941306591033936 validation loss: 1.6366758346557617
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.5814 | 0.3380
# -------------------------------
# -------Source city: Blairgowrie-------
# -------------------------------
# (568, 6) (568, 3)
# Early stopping at epoch: 65
# epoch 65 train loss: 0.6004093885421753 validation loss: 0.5740813612937927
# Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.5814 | 0.3380
# -------Target city: Perth--------
# (108, 6) (108, 3)
# Early stopping at epoch: 157
# epoch 157 train loss: 0.45552563667297363 validation loss: 0.744016170501709
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2824 | 0.4091 | 0.8395 | 0.4811
# Early stopping at epoch: 41
# epoch 41 train loss: 0.7003467679023743 validation loss: 0.34898677468299866
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2731 | 0.3775 | 0.7863 | 0.4677
# -------Target city: HK--------
# (180, 6) (180, 3)
# Early stopping at epoch: 46
# epoch 46 train loss: 0.8818159831894768 validation loss: 0.5188031792640686
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2179 | 0.2236 | 0.7981 | 0.5433
# Early stopping at epoch: 24
# epoch 24 train loss: 0.8132673501968384 validation loss: 0.9421012997627258
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3196 | 0.4577 | 0.7618 | 0.5827
# -------Target city: PALO--------
# (126, 6) (126, 3)
# Early stopping at epoch: 22
# epoch 22 train loss: 0.7163827419281006 validation loss: 1.1138747930526733
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9153 | 1.8045 | 1.1084 | 0.7015
# Early stopping at epoch: 45
# epoch 45 train loss: 0.6855440139770508 validation loss: 0.5802768468856812
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.4334 | 0.6583 | 1.0091 | 0.8080
# -------Target city: DUNDEE--------
# (486, 6) (486, 3)
# Early stopping at epoch: 81
# epoch 81 train loss: 0.7059310019216506 validation loss: 0.8739185929298401
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2746 | 0.3023 | 0.6678 | 0.4619
# Early stopping at epoch: 23
# epoch 23 train loss: 0.6883946657180786 validation loss: 0.920829713344574
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.2481 | 0.2585 | 0.6798 | 0.4583
# -------Target city: BOULDER--------
# (342, 6) (342, 3)
# Early stopping at epoch: 29
# epoch 29 train loss: 0.5166736428780846 validation loss: 0.39657557010650635
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9718 | 1.9204 | 0.3970 | 0.2272
# Early stopping at epoch: 20
# epoch 20 train loss: 0.5895354747772217 validation loss: 0.5223210453987122
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.9661 | 1.9059 | 0.3968 | 0.2275
# -------Target city: Auchterarder--------
# (18, 6) (18, 3)
# Early stopping at epoch: 159
# epoch 159 train loss: 0.4298955202102661 validation loss: 1.0554472208023071
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# Early stopping at epoch: 137
# epoch 137 train loss: 0.6503259539604187 validation loss: 0.9511966109275818
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4672 | 0.2183
# -------Target city: Kinross--------
# (144, 6) (144, 3)
# Early stopping at epoch: 20
# epoch 20 train loss: 0.8637440800666809 validation loss: 1.2157683372497559
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.6509 | 0.4361
# Early stopping at epoch: 20
# epoch 20 train loss: 1.0370163917541504 validation loss: 1.0242972373962402
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.5972 | 1.1774 | 0.6974 | 0.5040
# -------Target city: Pitlochry--------
# (54, 6) (54, 3)
# Early stopping at epoch: 92
# epoch 92 train loss: 0.37625107169151306 validation loss: 0.41880130767822266
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# Early stopping at epoch: 67
# epoch 67 train loss: 0.11719172447919846 validation loss: 0.009348484687507153
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.3270 | 0.6119 | 0.3442 | 0.1971
# -------Target city: Crieff--------
# (36, 6) (36, 3)
# Early stopping at epoch: 112
# epoch 112 train loss: 0.41105973720550537 validation loss: 0.5267698764801025
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# Early stopping at epoch: 20
# epoch 20 train loss: 0.34756025671958923 validation loss: 0.3457834720611572
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.1115 | 0.2108 | 0.2379 | 0.1133
# -------Target city: Aberfeldy--------
# (36, 6) (36, 3)
# Early stopping at epoch: 47
# epoch 47 train loss: 0.3187795579433441 validation loss: 0.21269147098064423
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# Early stopping at epoch: 21
# epoch 21 train loss: 0.8071669936180115 validation loss: 0.21347853541374207
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.0754 | 0.1453 | 0.1715 | 0.0553
# -------Target city: Dunkeld--------
# (18, 6) (18, 3)
# Early stopping at epoch: 160
# epoch 160 train loss: 0.6216834187507629 validation loss: 0.0024735359475016594
# Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 1.0000 | 2.0000 | 0.4893 | 0.2394
# Early stopping at epoch: 107
# epoch 107 train loss: 0.5656859278678894 validation loss: 0.016236931085586548
# Wo Transfer Test MAPE1: SMAPE: RMSE:  MAE: | 0.8039 | 1.6078 | 0.4747 | 0.2254

# %% [markdown]
# ### write result to file

# %%
metric_list = ['mape', 'smape', 'rmse', 'mae']

for i in range(len(metric_list)):

    save_df = pd.DataFrame(transfer_rec[:,:,i], index = city_list, columns= city_list)
    save_df.index.name = 'source \ target'
    save_df.loc['wo_trans'] = wo_transfer_rec[:,i]

    save_df.to_csv('res/station/' + model_name + '_pred_' + str(pred_len) + '_' + metric_list[i] + '.csv')
